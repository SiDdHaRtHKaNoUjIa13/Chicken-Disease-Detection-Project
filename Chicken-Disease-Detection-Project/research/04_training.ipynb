# %%
import os

# %%
# %pwd
# Out:
# 'c:\\Users\\Siddharth kanoujia\\OneDrive\\Desktop\\CICD Deployment\\Chicken-Disease-Detection-Project\\research'

# %%
os.chdir("../")

# %%
# %pwd
# Out:
# 'c:\\Users\\Siddharth kanoujia\\OneDrive\\Desktop\\CICD Deployment\\Chicken-Disease-Detection-Project'

# %%
from dataclasses import dataclass
from pathlib import Path 

@dataclass(frozen = True)
class TrainingConfig:
    root_dir: Path
    trained_model_path: Path 
    updated_base_model_path: Path
    training_data : Path 
    params_epochs: int
    params_batch_size:int
    params_is_augmentation: bool
    params_image_size: list 



# we willbe using the prepare callbacks in out training as already done before 
@dataclass(frozen=True)
class PrepareCallbacksConfig:
    root_dir: Path
    tensorboard_root_log_dir: Path 
    checkpoint_model_filepath: Path

# %%
from ChickenDisease.constants import *
from ChickenDisease.utils.common import read_yaml , create_directories
import tensorflow as tf
tf.config.run_functions_eagerly(True)

# %%
class ConfigurationManager:
    def __init__(
        self, 
        config_filepath = CONFIG_FILE_PATH,
        params_filepath = PARAMS_FILE_PATH):
        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)
        create_directories([self.config.artifacts_root])


    
    def get_prepare_callback_config(self) -> PrepareCallbacksConfig:
        config = self.config.prepare_callbacks
        model_ckpt_dir = os.path.dirname(config.checkpoint_model_filepath)
        create_directories([
            Path(model_ckpt_dir),
            Path(config.tensorboard_root_log_dir)
        ])

        prepare_callback_config = PrepareCallbacksConfig(
            root_dir=Path(config.root_dir),
            tensorboard_root_log_dir=Path(config.tensorboard_root_log_dir),
            checkpoint_model_filepath=Path(config.checkpoint_model_filepath)
        )

        return prepare_callback_config
    




    def get_training_config(self) -> TrainingConfig:
        training = self.config.training
        prepare_base_model = self.config.prepare_base_model
        params = self.params
        training_data = os.path.join(self.config.data_ingestion.unzip_dir, "Chicken-fecal-images")
        create_directories([
            Path(training.root_dir)
        ])

        training_config = TrainingConfig(
            root_dir=Path(training.root_dir),
            trained_model_path=Path(training.trained_model_path),
            updated_base_model_path=Path(prepare_base_model.updated_base_model_path),
            training_data=Path(training_data),
            params_epochs=params.EPOCHS,
            params_batch_size=params.BATCH_SIZE,
            params_is_augmentation=params.AUGMENTATION,
            params_image_size=params.IMAGE_SIZE
        )

        return training_config

# %%
import time

# %%
class PrepareCallback:
    def __init__(self, config: PrepareCallbacksConfig):
        self.config = config


    
    @property
    def _create_tb_callbacks(self):
        timestamp = time.strftime("%Y-%m-%d-%H-%M-%S")
        tb_running_log_dir = os.path.join(
            self.config.tensorboard_root_log_dir,
            f"tb_logs_at_{timestamp}",
        )
        return tf.keras.callbacks.TensorBoard(log_dir=tb_running_log_dir)
    

    @property
    def _create_ckpt_callbacks(self):
        return tf.keras.callbacks.ModelCheckpoint(
            filepath=self.config.checkpoint_model_filepath,
            save_best_only=True
        )


    def get_tb_ckpt_callbacks(self):
        return [
            self._create_tb_callbacks,
            self._create_ckpt_callbacks
        ]

# %%
import os
import urllib.request as request 
from zipfile import ZipFile
import time

# %%
class Training:
    def __init__(self, config: TrainingConfig):
        self.config = config
    
    def get_base_model(self):
        self.model = tf.keras.models.load_model(
        self.config.updated_base_model_path
    )

        optimizer = tf.keras.optimizers.SGD(
            learning_rate=0.001
        )

        self.model.compile(
            optimizer=optimizer,
            loss=tf.keras.losses.CategoricalCrossentropy(),
            metrics=["accuracy"],
            run_eagerly=True
    )
    
    def train_valid_generator(self):

        datagenerator_kwargs = dict(
            rescale = 1./255,
            validation_split=0.20
        )

        dataflow_kwargs = dict(
            target_size=self.config.params_image_size[:-1],
            batch_size=self.config.params_batch_size,
            interpolation="bilinear"
        )

        valid_datagenerator = tf.keras.preprocessing.image.ImageDataGenerator(
            **datagenerator_kwargs
        )

        self.valid_generator = valid_datagenerator.flow_from_directory(
            directory=self.config.training_data,
            subset="validation",
            shuffle=False,
            **dataflow_kwargs
        )

        if self.config.params_is_augmentation:
            train_datagenerator = tf.keras.preprocessing.image.ImageDataGenerator(
                rotation_range=40,
                horizontal_flip=True,
                width_shift_range=0.2,
                height_shift_range=0.2,
                shear_range=0.2,
                zoom_range=0.2,
                **datagenerator_kwargs
            )
        else:
            train_datagenerator = valid_datagenerator

        self.train_generator = train_datagenerator.flow_from_directory(
            directory=self.config.training_data,
            subset="training",
            shuffle=True,
            **dataflow_kwargs
        )

    @staticmethod
    def save_model(path: Path, model: tf.keras.Model):
        model.save(path)


    def train(self, callback_list: list):
        self.steps_per_epoch = self.train_generator.samples // self.train_generator.batch_size
        self.validation_steps = self.valid_generator.samples // self.valid_generator.batch_size

        self.model.fit(
            self.train_generator,
            epochs=self.config.params_epochs,
            steps_per_epoch=self.steps_per_epoch,
            validation_steps=self.validation_steps,
            validation_data=self.valid_generator,
            callbacks=callback_list
        )

        self.save_model(
            path=self.config.trained_model_path,
            model=self.model
        )

# %%
try:
    config = ConfigurationManager()
    prepare_callbacks_config = config.get_prepare_callback_config()
    prepare_callbacks = PrepareCallback(config=prepare_callbacks_config)
    callback_list = prepare_callbacks.get_tb_ckpt_callbacks()

    training_config = config.get_training_config()
    training = Training(config=training_config)
    training.get_base_model()
    training.train_valid_generator()
    training.train(
        callback_list=callback_list
    )
    
except Exception as e:
    raise e
# Out:
# [2026-01-01 21:29:51,837 : INFO: common: yaml file: config\config.yaml loaded successfully]
# [2026-01-01 21:29:51,879 : INFO: common: yaml file: params.yaml loaded successfully]
# [2026-01-01 21:29:51,883 : INFO: common: created directory at: artifacts]
# [2026-01-01 21:29:51,886 : INFO: common: created directory at: artifacts\prepare_callbacks\checkpoint_dir]
# [2026-01-01 21:29:51,892 : INFO: common: created directory at: artifacts\prepare_callbacks\tensorboard_log_dir]
# [2026-01-01 21:29:51,897 : INFO: common: created directory at: artifacts\training]
# [2026-01-01 21:29:53,281 : WARNING: saving_utils: Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.]
# Found 78 images belonging to 2 classes.
# Found 312 images belonging to 2 classes.
# c:\Python310\lib\site-packages\tensorflow\python\data\ops\structured_function.py:258: UserWarning: Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable_debug_mode()`.
#   warnings.warn(
# Epoch 1/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 32s/step - accuracy: 0.4712 - loss: 1.3386 [2026-01-01 21:40:33,001 : WARNING: saving_api: You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`. ]
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 635s 33s/step - accuracy: 0.4899 - loss: 1.3941 - val_accuracy: 0.8594 - val_loss: 0.4238
# Epoch 2/30
#  1/19 ━━━━━━━━━━━━━━━━━━━━ 10:36 35s/step - accuracy: 0.7500 - loss: 0.5389
# c:\Python310\lib\site-packages\keras\src\trainers\epoch_iterator.py:116: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 68s 2s/step - accuracy: 0.7500 - loss: 0.5389 - val_accuracy: 0.3906 - val_loss: 1.0328
# Epoch 3/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 572s 30s/step - accuracy: 0.6622 - loss: 0.7092 - val_accuracy: 0.4219 - val_loss: 1.0932
# Epoch 4/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 52s 1s/step - accuracy: 0.3750 - loss: 1.0122 - val_accuracy: 0.6094 - val_loss: 0.9845
# Epoch 5/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 27s/step - accuracy: 0.6554 - loss: 0.9128 [2026-01-01 22:00:52,404 : WARNING: saving_api: You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`. ]
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 527s 29s/step - accuracy: 0.7027 - loss: 0.6543 - val_accuracy: 0.8281 - val_loss: 0.3575
# Epoch 6/30
#  1/19 ━━━━━━━━━━━━━━━━━━━━ 7:17 24s/step - accuracy: 0.7500 - loss: 0.3912[2026-01-01 22:01:38,486 : WARNING: saving_api: You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`. ]
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 46s 1s/step - accuracy: 0.7500 - loss: 0.3912 - val_accuracy: 0.7812 - val_loss: 0.3575
# Epoch 7/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 21s/step - accuracy: 0.8861 - loss: 0.2959 [2026-01-01 22:08:40,241 : WARNING: saving_api: You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`. ]
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 422s 22s/step - accuracy: 0.8919 - loss: 0.2748 - val_accuracy: 0.8906 - val_loss: 0.2957
# Epoch 8/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 46s 1s/step - accuracy: 0.8125 - loss: 0.4302 - val_accuracy: 0.8750 - val_loss: 0.3025
# Epoch 9/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 23s/step - accuracy: 0.8687 - loss: 0.3534 [2026-01-01 22:17:04,713 : WARNING: saving_api: You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`. ]
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 459s 24s/step - accuracy: 0.8953 - loss: 0.3043 - val_accuracy: 0.8906 - val_loss: 0.2565
# Epoch 10/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 52s 1s/step - accuracy: 0.9375 - loss: 0.2449 - val_accuracy: 0.7969 - val_loss: 0.3720
# Epoch 11/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22s/step - accuracy: 0.8751 - loss: 0.3057 [2026-01-01 22:25:24,541 : WARNING: saving_api: You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`. ]
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 448s 23s/step - accuracy: 0.8547 - loss: 0.3584 - val_accuracy: 0.8906 - val_loss: 0.2465
# Epoch 12/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 51s 1s/step - accuracy: 0.8750 - loss: 0.3120 - val_accuracy: 0.9375 - val_loss: 0.2635
# Epoch 13/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22s/step - accuracy: 0.9166 - loss: 0.2040 [2026-01-01 22:33:36,116 : WARNING: saving_api: You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`. ]
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 440s 23s/step - accuracy: 0.9054 - loss: 0.2204 - val_accuracy: 0.9375 - val_loss: 0.2412
# Epoch 14/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 49s 1s/step - accuracy: 0.8125 - loss: 0.3445 - val_accuracy: 0.9062 - val_loss: 0.2601
# Epoch 15/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22s/step - accuracy: 0.8981 - loss: 0.2631 [2026-01-01 22:41:45,380 : WARNING: saving_api: You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`. ]
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 440s 23s/step - accuracy: 0.8953 - loss: 0.2678 - val_accuracy: 0.9375 - val_loss: 0.2324
# Epoch 16/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 50s 1s/step - accuracy: 0.8750 - loss: 0.2165 - val_accuracy: 0.7656 - val_loss: 0.4111
# Epoch 17/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 440s 23s/step - accuracy: 0.9155 - loss: 0.2328 - val_accuracy: 0.7656 - val_loss: 0.4068
# Epoch 18/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 46s 1s/step - accuracy: 1.0000 - loss: 0.0951 - val_accuracy: 0.7656 - val_loss: 0.4133
# Epoch 19/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22s/step - accuracy: 0.8907 - loss: 0.2342 [2026-01-01 22:58:06,728 : WARNING: saving_api: You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`. ]
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 445s 23s/step - accuracy: 0.9189 - loss: 0.2167 - val_accuracy: 0.9219 - val_loss: 0.2193
# Epoch 20/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 48s 1s/step - accuracy: 0.8750 - loss: 0.2530 - val_accuracy: 0.8594 - val_loss: 0.3126
# Epoch 21/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 440s 23s/step - accuracy: 0.9054 - loss: 0.2069 - val_accuracy: 0.9375 - val_loss: 0.2263
# Epoch 22/30
#  1/19 ━━━━━━━━━━━━━━━━━━━━ 7:14 24s/step - accuracy: 0.8750 - loss: 0.2946[2026-01-01 23:07:01,683 : WARNING: saving_api: You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`. ]
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 47s 1s/step - accuracy: 0.8750 - loss: 0.2946 - val_accuracy: 0.9375 - val_loss: 0.2143
# Epoch 23/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 23s/step - accuracy: 0.8750 - loss: 0.2283 [2026-01-01 23:14:54,676 : WARNING: saving_api: You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`. ]
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 473s 25s/step - accuracy: 0.9054 - loss: 0.1932 - val_accuracy: 0.9375 - val_loss: 0.2110
# Epoch 24/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 54s 1s/step - accuracy: 0.8750 - loss: 0.3325 - val_accuracy: 0.9219 - val_loss: 0.2240
# Epoch 25/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 23s/step - accuracy: 0.9313 - loss: 0.1903 [2026-01-01 23:23:35,351 : WARNING: saving_api: You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`. ]
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 467s 24s/step - accuracy: 0.9358 - loss: 0.1821 - val_accuracy: 0.9375 - val_loss: 0.2079
# Epoch 26/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 50s 1s/step - accuracy: 0.8125 - loss: 0.3150 - val_accuracy: 0.9062 - val_loss: 0.2381
# Epoch 27/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 23s/step - accuracy: 0.9226 - loss: 0.2065 [2026-01-01 23:32:00,870 : WARNING: saving_api: You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`. ]
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 456s 24s/step - accuracy: 0.9324 - loss: 0.1807 - val_accuracy: 0.9375 - val_loss: 0.2063
# Epoch 28/30
#  1/19 ━━━━━━━━━━━━━━━━━━━━ 8:08 27s/step - accuracy: 0.9375 - loss: 0.1941[2026-01-01 23:32:51,023 : WARNING: saving_api: You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`. ]
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 50s 1s/step - accuracy: 0.9375 - loss: 0.1941 - val_accuracy: 0.9375 - val_loss: 0.2050
# Epoch 29/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 442s 23s/step - accuracy: 0.9223 - loss: 0.1766 - val_accuracy: 0.9375 - val_loss: 0.2061
# Epoch 30/30
#  1/19 ━━━━━━━━━━━━━━━━━━━━ 7:21 25s/step - accuracy: 0.8125 - loss: 0.3134[2026-01-01 23:41:00,269 : WARNING: saving_api: You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`. ]
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 47s 1s/step - accuracy: 0.8125 - loss: 0.3134 - val_accuracy: 0.9531 - val_loss: 0.2028
# [2026-01-01 23:41:00,610 : WARNING: saving_api: You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`. ]
